# %% [markdown]
# # Test the model
#
# ### initialize 200 episodes since the model already converged at 5m steps

# %%
from stable_baselines3 import DQN
import json
import gymnasium as gym
import os
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, VecNormalize
import ale_py
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
import numpy as np
from stable_baselines3.common.evaluation import evaluate_policy
import time
import torch
from torch.utils.tensorboard import SummaryWriter

PATH1 = "./DQN_1_stable_32_1e4_5m/sb3_pong_models/pong_dqn_final_model.zip"
PATH2 = "./DQN_2_stable_256_25e4_5m/sb3_pong_models/pong_dqn_final_model.zip"
TB1 = "./DQN_1_stable_32_1e4_5m/eval/"
TB2 = "./DQN_2_stable_256_25e4_5m/eval/"
os.makedirs(TB1, exist_ok=True)
os.makedirs(TB2, exist_ok=True)

EPISODES = 200
config = {
    "env_name": "PongNoFrameskip-v4",
    "num_envs": 1,
    "seed": 100,
}
# enable this for seeable testing
# eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"], env_kwargs={"render_mode": "human"})

# non render testing
eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"])
env = VecFrameStack(eval_env, n_stack=4)
# env = eval_env
model = DQN.load(PATH2, env=env)
# print(model.policy)
vec_env = model.get_env()

writer = SummaryWriter(log_dir=TB2)
for episode in range(EPISODES):
    obs = vec_env.reset()
    done = False
    total_reward = 0
    q_val_list = []
    td_errors = []
    step_count = 0
    while not done:
        obs_tensor = torch.tensor(obs, dtype=torch.float32).to(model.device)
        q_values = model.q_net(obs_tensor)
        q_val_list.append(q_values.detach().cpu().numpy().mean())

        action, _ = model.predict(obs, deterministic=True)
        next_obs, rewards, dones, info = vec_env.step(action)
        with torch.no_grad():
            next_q = model.q_net(torch.tensor(next_obs, dtype=torch.float32).to(model.device)).max(1)[0]
        td_error = abs(rewards[0] + model.gamma * next_q.item() - q_values.max(1)[0].item())
        td_errors.append(td_error)
        done = dones[0]
        total_reward += rewards[0]
        step_count += 1
        obs = next_obs
        
    mean_q_value = np.mean(q_val_list)
    mean_td = np.mean(td_errors)
    writer.add_scalar("eval/episode_reward", total_reward, episode)
    writer.add_scalar("eval/mean_q_value", mean_q_value, episode)
    writer.add_scalar("eval/td_error", mean_td, episode)
    writer.add_scalar("eval/episode_length", step_count, episode)
    print(f"Episode {episode+1}: Reward={total_reward:.2f}, Mean Q={mean_q_value:.3f}, Mean TD Error (loss)={mean_td:.4f}, Steps={step_count}")
# Out:
# Wrapping the env in a VecTransposeImage.
# Episode 1: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0279, Steps=1852
# Episode 2: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3805
# Episode 3: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1851
# Episode 4: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1971
# Episode 5: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1849
# Episode 6: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1852
# Episode 7: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3799
# Episode 8: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0615, Steps=3499
# Episode 9: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3801
# Episode 10: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=
Reward=14.00, Mean Q=1.142, Mean TD Error (loss)=0.0552, Steps=3150
# Episode 143: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1974
# Episode 144: Reward=14.00, Mean Q=1.142, Mean TD Error (loss)=0.0551, Steps=3146
# Episode 145: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0278, Steps=1854
# Episode 146: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0282, Steps=1856
# Episode 147: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3801
# Episode 148: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1977
# Episode 149: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0613, Steps=3494
# Episode 150: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1975
# Episode 151: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1974
# Episode 152: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0613, Steps=3496
# Episode 153: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1850
# Episode 154: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3802
# Episode 155: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3805
# Episode 156: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0278, Steps=1854
# Episode 157: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1851
# Episode 158: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1976
# Episode 159: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0615, Steps=3499
# Episode 160: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1849
# Episode 161: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1849
# Episode 162: Reward=15.00, Mean Q=1.139, Mean TD Error (loss)=0.0546, Steps=3296
# Episode 163: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1849
# Episode 164: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3801
# Episode 165: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1975
# Episode 166: Reward=15.00, Mean Q=1.139, Mean TD Error (loss)=0.0546, Steps=3296
# Episode 167: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1974
# Episode 168: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0615, Steps=3499
# Episode 169: Reward=14.00, Mean Q=1.142, Mean TD Error (loss)=0.0552, Steps=3150
# Episode 170: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1852
# Episode 171: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1974
# Episode 172: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1977
# Episode 173: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3800
# Episode 174: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1852
# Episode 175: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1976
# Episode 176: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3805
# Episode 177: Reward=15.00, Mean Q=1.139, Mean TD Error (loss)=0.0546, Steps=3296
# Episode 178: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3800
# Episode 179: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0615, Steps=3499
# Episode 180: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0279, Steps=1853
# Episode 181: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0615, Steps=3499
# Episode 182: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1975
# Episode 183: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3804
# Episode 184: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1977
# Episode 185: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3804
# Episode 186: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0613, Steps=3494
# Episode 187: Reward=19.00, Mean Q=1.260, Mean TD Error (loss)=0.0309, Steps=1975
# Episode 188: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3805
# Episode 189: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1973
# Episode 190: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0278, Steps=1854
# Episode 191: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0279, Steps=1855
# Episode 192: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0613, Steps=3496
# Episode 193: Reward=19.00, Mean Q=1.261, Mean TD Error (loss)=0.0309, Steps=1972
# Episode 194: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1850
# Episode 195: Reward=19.00, Mean Q=1.290, Mean TD Error (loss)=0.0279, Steps=1851
# Episode 196: Reward=14.00, Mean Q=1.090, Mean TD Error (loss)=0.0613, Steps=3500
# Episode 197: Reward=19.00, Mean Q=1.289, Mean TD Error (loss)=0.0279, Steps=1853
# Episode 198: Reward=13.00, Mean Q=1.103, Mean TD Error (loss)=0.0601, Steps=3805
# Episode 199: Reward=14.00, Mean Q=1.142, Mean TD Error (loss)=0.0552, Steps=3150
# Episode 200: Reward=14.00, Mean Q=1.142, Mean TD Error (loss)=0.0552, Steps=3150

# %% [markdown]
# ## SEE GAMEPLAY

# %%
# change directory here for model zip file
save_dir = "./sb3_pong_models_dqn"
model_path = os.path.join(save_dir, "pong_dqn_final_model.zip")
config = {
    "env_name": "PongNoFrameskip-v4",
    "num_envs": 1,
    "seed": 100,
}
eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"], env_kwargs={"render_mode": "human"})
eval_env = VecFrameStack(eval_env, n_stack=4)
model = DQN.load(model_path, env=eval_env)
obs = eval_env.reset()
done = False

while not done:
    eval_env.render()
    action, _states = model.predict(obs, deterministic=True)
    obss, rewards, dones, infos = eval_env.step(action)
    done = dones[0]
