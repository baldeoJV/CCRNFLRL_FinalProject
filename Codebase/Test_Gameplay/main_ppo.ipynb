# %%
import gymnasium as gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, VecNormalize
import ale_py
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.callbacks import BaseCallback, CheckpointCallback
import numpy as np
from stable_baselines3.common.evaluation import evaluate_policy
import time
import torch
from torch.utils.tensorboard import SummaryWriter
import time
import json

PATH2 = "./PPO_2_stable_32_1e4_5m/sb3_pong_models_ppo/pong_ppo_final_model.zip"
PATH1 = "./PPO_1_stable_256_25e4_5m/sb3_pong_models_ppo/pong_ppo_final_model.zip"
TB2 = "./PPO_2_stable_32_1e4_5m/eval_1/"
TB1 = "./PPO_1_stable_256_25e4_5m/eval_1/"

# %% [markdown]
# ## Check gameplay, just choose your zip file

# %%
config = {
    "env_name": "PongNoFrameskip-v4",
    "num_envs": 1,
    "seed": 100,
}
eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"], env_kwargs={"render_mode": "human"})
# eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"])

env = VecFrameStack(eval_env, n_stack=4)
# env = eval_env
model_path = "./sb3_pong_models_ppo/pong_ppo_final_model.zip"
model = PPO.load(model_path, env=env)
print(model.policy)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1500):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Wrapping the env in a VecTransposeImage.
# CustomCnnPolicy(
#   (features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): CustomCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential()
#     (value_net): Sequential()
#   )
#   (action_net): Linear(in_features=512, out_features=6, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Test the ppo models in 200 episodes

# %%
PATH2 = "./PPO_2_stable_32_1e4_5m/sb3_pong_models_ppo/pong_ppo_final_model.zip"
PATH1 = "./PPO_1_stable_256_25e4_5m/sb3_pong_models_ppo/pong_ppo_final_model.zip"
TB2 = "./PPO_2_stable_32_1e4_5m/eval/"
TB1 = "./PPO_1_stable_256_25e4_5m/eval/"
os.makedirs(TB1, exist_ok=True)
os.makedirs(TB2, exist_ok=True)

EPISODES = 200
config = {
    "env_name": "PongNoFrameskip-v4",
    "num_envs": 1,
    "seed": 100,
}

eval_env = make_atari_env(config["env_name"], n_envs=config["num_envs"], seed=config["seed"])
env = VecFrameStack(eval_env, n_stack=4)

model = PPO.load(PATH2, env=env)
vec_env = model.get_env()

writer = SummaryWriter(log_dir=TB2)

for episode in range(EPISODES):
    obs = vec_env.reset()
    done = False
    total_reward = 0
    value_list = []
    entropy_list = []
    step_count = 0

    while not done:

        obs_tensor = torch.as_tensor(obs).to(model.device)

        with torch.no_grad():
            dist = model.policy.get_distribution(obs_tensor)
            value = model.policy.predict_values(obs_tensor)
            entropy = dist.entropy().mean().item()

        value_list.append(value.mean().item())
        entropy_list.append(entropy)

        action, _ = model.predict(obs, deterministic=True)
        obs, rewards, dones, info = vec_env.step(action)

        total_reward += rewards[0]
        done = dones[0]
        step_count += 1

    mean_value = np.mean(value_list)
    mean_entropy = np.mean(entropy_list)

    writer.add_scalar("eval/episode_reward", total_reward, episode)
    writer.add_scalar("eval/value_mean", mean_value, episode)
    writer.add_scalar("eval/entropy", mean_entropy, episode)
    writer.add_scalar("eval/episode_length", step_count, episode)

    print(f"Episode {episode+1}: Reward={total_reward:.2f}, Value={mean_value:.3f}, Entropy={mean_entropy:.3f}, Steps={step_count}")

writer.close()
# Out:
# Wrapping the env in a VecTransposeImage.
# Episode 1: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2607
# Episode 2: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 3: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 4: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 5: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 6: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 7: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 8: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 9: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 10: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 11: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2185
# Episode 12: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 13: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 14: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 15: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2611
# Episode 16: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 17: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 18: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 19: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2185
# Episode 20: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2231
# Episode 21: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 22: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 23: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 24: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 25: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 26: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 27: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2231
# Episode 28: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 29: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 30: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 31: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 32: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 33: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 34: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2606
# Episode 35: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 36: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 37: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 38: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2610
# Episode 39: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 40: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 41: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 42: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 43: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 44: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 45: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 46: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2606
# Episode 47: Reward=21.00, Value=0.745, Entropy=0.700, Steps=2605
# Episode 48: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 49: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 50: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 51: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 52: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 53: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 54: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 55: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 56: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2187
# Episode 57: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 58: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 59: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2230
# Episode 60: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 61: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 62: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 63: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 64: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 65: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 66: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 67: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 68: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 69: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 70: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 71: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 72: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 73: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 74: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 75: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 76: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 77: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 78: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 79: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 80: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 81: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 82: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 83: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 84: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 85: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 86: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 87: Reward=21.00, Value=0.745, Entropy=0.700, Steps=2605
# Episode 88: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 89: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 90: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2231
# Episode 91: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 92: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2185
# Episode 93: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 94: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 95: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 96: Reward=21.00, Value=0.745, Entropy=0.700, Steps=2605
# Episode 97: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2234
# Episode 98: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2230
# Episode 99: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 100: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 101: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2185
# Episode 102: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 103: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 104: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 105: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 106: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 107: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 108: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 109: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 110: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 111: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 112: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 113: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 114: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 115: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 116: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2610
# Episode 117: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2187
# Episode 118: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 119: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 120: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 121: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 122: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2234
# Episode 123: Reward=21.00, Value=0.745, Entropy=0.701, Steps=2604
# Episode 124: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 125: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 126: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 127: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 128: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 129: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2182
# Episode 130: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 131: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2611
# Episode 132: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 133: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 134: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 135: Reward=21.00, Value=0.745, Entropy=0.700, Steps=2605
# Episode 136: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 137: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 138: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 139: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 140: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2187
# Episode 141: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 142: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 143: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 144: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2233
# Episode 145: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 146: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2611
# Episode 147: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 148: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2610
# Episode 149: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2230
# Episode 150: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 151: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 152: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 153: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 154: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2185
# Episode 155: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 156: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 157: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 158: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 159: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 160: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 161: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 162: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 163: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2604
# Episode 164: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2184
# Episode 165: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 166: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 167: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 168: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 169: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 170: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 171: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2607
# Episode 172: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2610
# Episode 173: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 174: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2607
# Episode 175: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2609
# Episode 176: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 177: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2186
# Episode 178: Reward=19.00, Value=0.792, Entropy=0.814, Steps=2183
# Episode 179: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 180: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 181: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2235
# Episode 182: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 183: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2187
# Episode 184: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2610
# Episode 185: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2187
# Episode 186: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2230
# Episode 187: Reward=21.00, Value=0.744, Entropy=0.702, Steps=2608
# Episode 188: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 189: Reward=21.00, Value=0.744, Entropy=0.701, Steps=2606
# Episode 190: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2609
# Episode 191: Reward=21.00, Value=0.738, Entropy=0.707, Steps=2610
# Episode 192: Reward=18.00, Value=0.767, Entropy=0.809, Steps=2232
# Episode 193: Reward=21.00, Value=0.745, Entropy=0.700, Steps=2605
# Episode 194: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2605
# Episode 195: Reward=21.00, Value=0.738, Entropy=0.705, Steps=2606
# Episode 196: Reward=18.00, Value=0.767, Entropy=0.808, Steps=2236
# Episode 197: Reward=21.00, Value=0.738, Entropy=0.706, Steps=2608
# Episode 198: Reward=19.00, Value=0.791, Entropy=0.814, Steps=2188
# Episode 199: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
# Episode 200: Reward=18.00, Value=0.766, Entropy=0.809, Steps=2237
